# %%
## Code Cell
print("파이썬 분석 첫수업, 화이팅~!")
# Out:
# 파이썬 분석 첫수업, 화이팅~!

# %%
# 파이썬 함수의 종류는?

# %%
## 이미지 함수 불러오기
from IPython.display import Image
Image(url='https://dimg.donga.com/wps/SPORTS/IMAGE/2023/01/11/117383932.1.jpg')
# Out:
# <img src="https://dimg.donga.com/wps/SPORTS/IMAGE/2023/01/11/117383932.1.jpg"/>

# %%
## Youtube 함수 불러 오기
from IPython.lib.display import YouTubeVideo
YouTubeVideo('KL1MIuBfWe0', width='800', height='550')
